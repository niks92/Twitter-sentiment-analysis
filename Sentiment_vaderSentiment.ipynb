# %%
# Import all required libraries

import nltk
import numpy as np
import re
import pandas as pd 
import pylab as pl
import matplotlib.pyplot as plt

from nltk.tokenize import WordPunctTokenizer
from bs4 import BeautifulSoup
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA, TruncatedSVD

from sklearn import metrics
from mpl_toolkits.mplot3d import Axes3D

from matplotlib import pyplot

#plt.style.use('fivethirtyeight')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# !pip install vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyser = SentimentIntensityAnalyzer()

# !pip install datashader
import datashader as ds
import datashader.transfer_functions as tf
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.6/dist-packages (3.2.1)
# Requirement already satisfied: datashader in /usr/local/lib/python3.6/dist-packages (0.6.9)
# Requirement already satisfied: pandas>=0.20.3 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.22.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from datashader) (1.14.6)
# Requirement already satisfied: numba>=0.37.0 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.40.1)
# Requirement already satisfied: toolz>=0.7.4 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.9.0)
# Requirement already satisfied: datashape>=0.5.1 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.5.2)
# Requirement already satisfied: xarray>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.11.3)
# Requirement already satisfied: param>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from datashader) (1.8.2)
# Requirement already satisfied: colorcet>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from datashader) (1.0.1)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.6/dist-packages (from datashader) (1.0.4)
# Requirement already satisfied: testpath<0.4 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.3.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.6/dist-packages (from datashader) (0.13.1)
# Requirement already satisfied: dask[complete]>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from datashader) (0.20.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from datashader) (1.1.0)
# Requirement already satisfied: pillow>=3.1.1 in /usr/local/lib/python3.6/dist-packages (from datashader) (4.1.1)
# Requirement already satisfied: pyct[cmd] in /usr/local/lib/python3.6/dist-packages (from datashader) (0.4.6)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.3->datashader) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.3->datashader) (2018.9)
# Requirement already satisfied: llvmlite>=0.25.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.37.0->datashader) (0.28.0)
# Requirement already satisfied: multipledispatch>=0.4.7 in /usr/local/lib/python3.6/dist-packages (from datashape>=0.5.1->datashader) (0.6.0)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.6/dist-packages (from bokeh->datashader) (1.11.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.6/dist-packages (from bokeh->datashader) (3.13)
# Requirement already satisfied: Jinja2>=2.7 in /usr/local/lib/python3.6/dist-packages (from bokeh->datashader) (2.10)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.6/dist-packages (from bokeh->datashader) (19.0)
# Requirement already satisfied: tornado>=4.3 in /usr/local/lib/python3.6/dist-packages (from bokeh->datashader) (4.5.3)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->datashader) (1.0.2)
# Requirement already satisfied: networkx>=1.8 in /usr/local/lib/python3.6/dist-packages (from scikit-image->datashader) (2.2)
# Requirement already satisfied: matplotlib>=1.3.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image->datashader) (3.0.3)
# Requirement already satisfied: cloudpickle>=0.2.1; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.18.0->datashader) (0.6.1)
# Requirement already satisfied: distributed>=1.22; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.18.0->datashader) (1.25.3)
# Requirement already satisfied: partd>=0.3.8; extra == "complete" in /usr/local/lib/python3.6/dist-packages (from dask[complete]>=0.18.0->datashader) (0.3.10)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=3.1.1->datashader) (0.46)
# Requirement already satisfied: requests; extra == "cmd" in /usr/local/lib/python3.6/dist-packages (from pyct[cmd]->datashader) (2.18.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.7->bokeh->datashader) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=16.8->bokeh->datashader) (2.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=1.8->scikit-image->datashader) (4.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=1.3.1->scikit-image->datashader) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=1.3.1->scikit-image->datashader) (1.0.1)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=1.22; extra == "complete"->dask[complete]>=0.18.0->datashader) (5.4.8)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.6/dist-packages (from distributed>=1.22; extra == "complete"->dask[complete]>=0.18.0->datashader) (0.5.6)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from distributed>=1.22; extra == "complete"->dask[complete]>=0.18.0->datashader) (0.1.4)
# Requirement already satisfied: tblib in /usr/local/lib/python3.6/dist-packages (from distributed>=1.22; extra == "complete"->dask[complete]>=0.18.0->datashader) (1.3.2)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.6/dist-packages (from distributed>=1.22; extra == "complete"->dask[complete]>=0.18.0->datashader) (2.1.0)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.6/dist-packages (from distributed>=1.22; extra == "complete"->dask[complete]>=0.18.0->datashader) (7.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.6/dist-packages (from partd>=0.3.8; extra == "complete"->dask[complete]>=0.18.0->datashader) (0.2.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests; extra == "cmd"->pyct[cmd]->datashader) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests; extra == "cmd"->pyct[cmd]->datashader) (2019.3.9)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests; extra == "cmd"->pyct[cmd]->datashader) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests; extra == "cmd"->pyct[cmd]->datashader) (3.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib>=1.3.1->scikit-image->datashader) (40.8.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.6/dist-packages (from zict>=0.1.3->distributed>=1.22; extra == "complete"->dask[complete]>=0.18.0->datashader) (1.0.0)

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Read the dataset

df = pd.read_csv("gdrive/My Drive/capstone-test/Saved_TweetsConsolidation.csv",encoding='UTF-8')
print(len(df))
# Out:
# 76978

# %%
# Number of unique tweets
unique_text = df.full_text.unique()
print(len(unique_text))
# Out:
# 13310

# %%
# Number of unique users
unique_user = df.user.unique()
len(unique_user)
# Out:
# 32879

# %%
df.head(2)
# Out:
#              id                                          full_text location  \
# 0  1.101820e+18  b'RT @sanghaviharsh: Indians look forward to t...      NaN
# 1  1.101820e+18  b'RT @davidfrawleyved: Why do the leaders of t...   Jaipur
#
#   hashtags                      created_at lang  is_retweeted          user
# 0      NaN  Sat Mar 02 12:36:30 +0000 2019   en         False  9.151790e+17
# 1      NaN  Sat Mar 02 12:36:27 +0000 2019   en         False  1.583831e+08

# %%
# Number of users with multiple tweets

df["id"].value_counts(ascending=False).head(2)
# Out:
# 1.102110e+18    2959
# 1.102090e+18    2869
# Name: id, dtype: int64

# %%
# Unique Languages
unique_lang = df.lang.unique()
len(unique_lang)
# Out:
# 1

# %%
# Number of Unique Locations
unique_location = df.location.unique()
len(unique_location)
df.location.value_counts().head(10)
# Out:
# India               5956
# New Delhi, India    1853
# Mumbai, India       1396
# Mumbai               945
# Bengaluru, India     894
# New Delhi            803
# Pakistan             656
# Bangalore            607
# भारत                 491
# Hyderabad, India     470
# Name: location, dtype: int64

# %%
# Unique Hashtags
unique_hashtags = df.hashtags.unique()
len(unique_hashtags)
# Out:
# 688

# %%
df.full_text.count()
# Out:
# 76978

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
    return input_txt

# %%
df['Clean_text'] = np.vectorize(remove_pattern)(df['full_text'], "@[\w]*")

# %%
# remove special characters, numbers, punctuations
df['Clean_text'] = df['Clean_text'].str.replace("[^a-zA-Z#]", " ")

# %%
df['Clean_text'] = df['Clean_text'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))

# %%
tokenized_tweet = df['Clean_text'].apply(lambda x: x.split())

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()

tokenized_tweet = tokenized_tweet.apply(lambda x: [stemmer.stem(i) for i in x]) # stemming
tokenized_tweet.head()
# Out:
# 0    [indian, look, forward, futur, with, renew, se...
# 1    [leader, opposit, hurl, wild, alleg, promot, c...
# 2    [report, modi, will, address, public, meet, fo...
# 3    [report, modi, will, address, public, meet, fo...
# 4    [believ, india, safe, hand, honor, prime, mini...
# Name: Clean_text, dtype: object

# %%
for i in range(len(tokenized_tweet)):
    tokenized_tweet[i] = ' '.join(tokenized_tweet[i])

df['Clean_text'] = tokenized_tweet

# %%
# tok = WordPunctTokenizer()
# pattern1 = r'@[A-Za-z0-9_]+'
# pattern2 = r'https?://[^ ]+'
# combined_pat = r'|'.join((pattern1, pattern2))
# print(combined_pat)

# www_pat = r'www.[^ ]+'
# negations_dic = {"isn't":"is not", "aren't":"are not", "wasn't":"was not", "weren't":"were not",
#                 "haven't":"have not","hasn't":"has not","hadn't":"had not","won't":"will not",
#                 "wouldn't":"would not", "don't":"do not", "doesn't":"does not","didn't":"did not",
#                 "can't":"can not","couldn't":"could not","shouldn't":"should not","mightn't":"might not",
#                 "mustn't":"must not"}
# neg_pattern = re.compile(r'\b(' + '|'.join(negations_dic.keys()) + r')\b')
# print(neg_pattern)
# Out:
# @[A-Za-z0-9_]+|https?://[^ ]+
# re.compile("\\b(isn't|aren't|wasn't|weren't|haven't|hasn't|hadn't|won't|wouldn't|don't|doesn't|didn't|can't|couldn't|shouldn't|mightn't|mustn't)\\b")

# %%
# def tweet_cleaner_updated(text):
#     soup = BeautifulSoup(text, 'lxml')   
#     souped = soup.get_text()
   
#     try:
#         bom_removed = souped.decode("utf-8-sig").replace(u"\ufffd", "?")
#     except:
#         bom_removed = souped
#     stripped = re.sub(combined_pat, '', bom_removed)
#     stripped = re.sub(www_pat, '', stripped)
#     #lower_case = stripped.lower()
#     #neg_handled = neg_pattern.sub(lambda x: negations_dic[x.group()], lower_case)
#     neg_handled = neg_pattern.sub(lambda x: negations_dic[x.group()], stripped)
#     letters_only = re.sub("[^a-zA-Z]", " ", neg_handled)
#     # During the letters_only process two lines above, it has created unnecessay white spaces,
#     # I will tokenize and join together to remove unneccessary white spaces
#     words = [x for x  in tok.tokenize(letters_only) if len(x) > 1]
#     return (" ".join(words)).strip()

# %%
# df['Clean_text'] = pd.DataFrame(clean_tweets,columns=['text'])

# %%
df.loc[:,('full_text','Clean_text')]
# Out:
#                                                full_text  \
# 0      b'RT @sanghaviharsh: Indians look forward to t...
# 1      b'RT @davidfrawleyved: Why do the leaders of t...
# 2      b'RT @TimesNow: Report: PM Modi will address a...
# 3      b'RT @TimesNow: Report: PM Modi will address a...
# 4      b'@hvgoenka I believe India is in safe hands o...
# 5      b'PM Narendra Modi says over 1.1 crore farmers...
# 6      b'RT @DunyaNews: Foreign media exposes Narendr...
# 7      b'RT @davidfrawleyved: As India under Narendra...
# 8      b"RT @IamMjahangeer: Pakistan's Prime Minister...
# 9      b'Narendra Modi and the struggle for India\xe2...
# 10     b'@narendramodi @BJP4India You should not worr...
# 11     b'"Abhinandan" Used To Mean Welcome, It Will C...
# 12     b'RT @news18dotcom: The constituency is being ...
# 13     b'If hating Modi makes you India haters \n\nTh...
# 14     b'RT @BT_India: PM Narendra Modi to launch Kal...
# 9             narendra modi struggl india soul http xndi
# 10     should worri better sens prevail thi countri p...
# 11     abhinandan use mean welcom will chang modi aft...
# 12     constitu be given saffron ahead visit dure whi...
# 13     hate modi make india hater nthen jasobaden ant...
# 14     narendra modi launch kalashnikov rifl manufact...
# 15     foreign media expos narendra modi elect win pr...
# 16     sign petit declar narendra modi global terrori...
# 17     hope those indian went over imran khan bash na...
# 18     sign petit declar narendra modi global terrori...
# 19     sign petit declar narendra modi global terrori...
# 20     india stop cost will fight grow prime minist n...
# 21     worst india pakistan crisi their nuclear comme...
# 22     dear thi logic even mistak pleas take your ble...
# 23     here narendra modi transform india n#bjpvijays...
# 24     #peacelovingpakistan nprime minist imran khan ...
# 25     imran khan hero pakistani media nnarendra modi...
# 26     after releas hero #abhinandanvarthaman pakista...
# 27     economist world over have talk about elus natu...
# 28     vijay sankalp bike ralli organ sabha elect wit...
# 29     ambedkar veri critic view gita which say provi...
# ...                                                  ...
# 76948  #loksabhaelect bihar share dai after decad san...
# 76949  hate narendra modi campaign opposit becom hate...
# 76950  huge problemat statement come from modi rafal ...
# 76951  mani shankar iyer extrem polit when describ na...
# 76952       support narendra modi #meraboothsabsemazboot
# 76953  #modiatconclav #letsconclav blast congress lis...
# 76954  mani shankar iyer extrem polit when describ na...
# 76955  question with kind weapon that both have affor...
# 76956  fear good when uncl speak famili afraid then f...
# 76957  rafal down modi pilot project npakistan parti ...
# 76958  mani shankar iyer extrem polit when describ na...
# 76959  india under narendra modi develop greater sens...
# 76960  make dyslexia target polit oppon there which n...
# 76961  previou govt fail bulletproof jacket arm forc ...
# 76962     thorough analyt piec must read http ojqglzupdo
# 76963  person feel nitin gadkari rajnath singh been p...
# 76964  #loksabhaelect bihar share dai after decad san...
# 76965  congress presid rahul gandhi mumbai earlier to...
# 76966  make dyslexia target polit oppon there which n...
# 76967  from sangam ganga yamuna saraswati from conflu...
# 76968  make dyslexia target polit oppon there which n...
# 76969  #paksymbolofpeac extrem terror what els extrem...
# 76970  mani shankar iyer extrem polit when describ na...
# 76971  parti guid modi hatr suspect arm forc modi nht...
# 76972  great long read from india fresh templat terro...
# 76973  former financ minist senior congress leader ch...
# 76974  make dyslexia target polit oppon there which n...
# 76975  mani shankar iyer extrem polit when describ na...
# 76976  make dyslexia target polit oppon there which n...
# 76977  thi realli rub seven decad dynasti noth develo...
#
# [76978 rows x 2 columns]

# %%
df[df.full_text.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, full_text, location, hashtags, created_at, lang, is_retweeted, user, Clean_text]
# Index: []

# %%
df[df.Clean_text.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, full_text, location, hashtags, created_at, lang, is_retweeted, user, Clean_text]
# Index: []

# %%
# Number of unique tweets
unique_clean_text = df.Clean_text.unique()
unique_full_text = df.full_text.unique()
print(len(unique_clean_text))
print(len(unique_full_text))
print(len(df))
# Out:
# 12388
# 13310
# 76978

# %%
df.drop_duplicates(subset=['Clean_text'], keep = 'first',inplace= True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df['Clean_text_length'] = df['Clean_text'].apply(len)
df.head()
# Out:
#              id                                          full_text location  \
# 0  1.101820e+18  b'RT @sanghaviharsh: Indians look forward to t...      NaN
# 1  1.101820e+18  b'RT @davidfrawleyved: Why do the leaders of t...   Jaipur
# 2  1.101820e+18  b'RT @TimesNow: Report: PM Modi will address a...  PATIALA
# 3  1.101820e+18  b'@hvgoenka I believe India is in safe hands o...      NaN
# 4  1.101820e+18  b'PM Narendra Modi says over 1.1 crore farmers...      NaN
#
#   hashtags                      created_at lang  is_retweeted          user  \
# 0      NaN  Sat Mar 02 12:36:30 +0000 2019   en         False  9.151790e+17
# 1      NaN  Sat Mar 02 12:36:27 +0000 2019   en         False  1.583831e+08
# 2      NaN  Sat Mar 02 12:36:24 +0000 2019   en         False  1.250421e+08
# 3      NaN  Sat Mar 02 12:36:20 +0000 2019   en         False  8.699160e+17
# 4      NaN  Sat Mar 02 12:36:19 +0000 2019   en         False  1.051370e+18
#
#                                           Clean_text  Clean_text_length
# 0  indian look forward futur with renew sens opti...                 73
# 1  leader opposit hurl wild alleg promot conspira...                 77
# 2  report modi will address public meet foundat s...                 86
# 3  believ india safe hand honor prime minist nare...                153
# 4  narendra modi say over crore farmer have kisan...                 88

# %%
df[df['Clean_text_length']==0]['Clean_text'] ## Looks like these are tweets with different languages or just hastags.
# We can simply drop these tweets
list = df[df['Clean_text_length']==0]['Clean_text'].index
list
# Out:
# Int64Index([235], dtype='int64')

# %%
df.drop(index = list,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12387 entries, 0 to 12387
# Data columns (total 10 columns):
# id                   12387 non-null float64
# full_text            12387 non-null object
# location             8792 non-null object
# hashtags             2203 non-null object
# created_at           12387 non-null object
# lang                 12387 non-null object
# is_retweeted         12387 non-null bool
# user                 12387 non-null float64
# Clean_text           12387 non-null object
# Clean_text_length    12387 non-null int64
# dtypes: bool(1), float64(2), int64(1), object(6)
# memory usage: 979.8+ KB

# %%
df.reset_index(drop=True,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12387 entries, 0 to 12386
# Data columns (total 10 columns):
# id                   12387 non-null float64
# full_text            12387 non-null object
# location             8792 non-null object
# hashtags             2203 non-null object
# created_at           12387 non-null object
# lang                 12387 non-null object
# is_retweeted         12387 non-null bool
# user                 12387 non-null float64
# Clean_text           12387 non-null object
# Clean_text_length    12387 non-null int64
# dtypes: bool(1), float64(2), int64(1), object(6)
# memory usage: 883.1+ KB

# %%
from textblob import TextBlob

# %%
TextBlob('Still enjoying the almost nice day out.  Now its down to +13, and calling for rain...').sentiment
# Out:
# Sentiment(polarity=0.3148148148148148, subjectivity=0.6296296296296297)

# %%
c=TextBlob("This was because he wasted time listing the failures of Congress prime  ministers. This was unnecessary because they are history and you, Narendra Modi, are the first Prime Minister in 30 years to be given a full mandate by the people of India")

# %%
def calculate_sentiment(Clean_text):
    return TextBlob(Clean_text).sentiment

# %%
def calculate_sentiment_analyser(Clean_text):    
    return analyser.polarity_scores(Clean_text)

# %%
df['sentiment']=df.Clean_text.apply(calculate_sentiment)
df['sentiment_analyser']=df.Clean_text.apply(calculate_sentiment_analyser)


s = pd.DataFrame(index = range(0,len(df)),columns= ['compound_score','compound_score_sentiment'])

for i in range(0,len(df)): 
  s['compound_score'][i] = df['sentiment_analyser'][i]['compound']
  
  if (df['sentiment_analyser'][i]['compound'] <= -0.05):
    s['compound_score_sentiment'][i] = 'Negative'    
  if (df['sentiment_analyser'][i]['compound'] >= 0.05):
    s['compound_score_sentiment'][i] = 'Positive'
  if ((df['sentiment_analyser'][i]['compound'] >= -0.05) & (df['sentiment_analyser'][i]['compound'] <= 0.05)):
    s['compound_score_sentiment'][i] = 'Neutral'
    
df['compound_score'] = s['compound_score']
df['compound_score_sentiment'] = s['compound_score_sentiment']
df.head(4)
# Out:
#              id                                          full_text location  \
# 0  1.101820e+18  b'RT @sanghaviharsh: Indians look forward to t...      NaN
# 1  1.101820e+18  b'RT @davidfrawleyved: Why do the leaders of t...   Jaipur
# 2  1.101820e+18  b'RT @TimesNow: Report: PM Modi will address a...  PATIALA
# 3  1.101820e+18  b'@hvgoenka I believe India is in safe hands o...      NaN
#
#   hashtags                      created_at lang  is_retweeted          user  \
# 0      NaN  Sat Mar 02 12:36:30 +0000 2019   en         False  9.151790e+17
# 1      NaN  Sat Mar 02 12:36:27 +0000 2019   en         False  1.583831e+08
# 2      NaN  Sat Mar 02 12:36:24 +0000 2019   en         False  1.250421e+08
# 3      NaN  Sat Mar 02 12:36:20 +0000 2019   en         False  8.699160e+17
#
#                                           Clean_text  Clean_text_length  \
# 0  indian look forward futur with renew sens opti...                 73
# 1  leader opposit hurl wild alleg promot conspira...                 77
# 2  report modi will address public meet foundat s...                 86
# 3  believ india safe hand honor prime minist nare...                153
#
#                                    sentiment  \
# 0               (-0.04999999999999996, 0.95)
# 1                                 (0.1, 0.4)
# 2                 (0.0, 0.06666666666666667)
# 3  (0.3444444444444445, 0.35555555555555557)
#
#                                   sentiment_analyser compound_score  \
# 0  {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'comp...         0.3182
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...              0
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...              0
# 3  {'neg': 0.064, 'neu': 0.581, 'pos': 0.355, 'co...          0.875
#
#   compound_score_sentiment
# 0                 Positive
# 1                  Neutral
# 2                  Neutral
# 3                 Positive

# %%
df.to_csv('gdrive/My Drive/capstone-test/unique_clean_tweets_sentiment_21.csv')

# %%
df.compound_score_sentiment.value_counts()
# Out:
# Neutral     5557
# Negative    3706
# Positive    3124
# Name: compound_score_sentiment, dtype: int64

# %%
df['Clean_text'].head()
# Out:
# 0    indian look forward futur with renew sens opti...
# 1    leader opposit hurl wild alleg promot conspira...
# 2    report modi will address public meet foundat s...
# 3    believ india safe hand honor prime minist nare...
# 4    narendra modi say over crore farmer have kisan...
# Name: Clean_text, dtype: object

# %%
#tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# Considering 3 grams and mimnimum frq as 0
tf_idf_vect = CountVectorizer(analyzer='word',ngram_range=(1,1),stop_words='english', min_df = 0.0001)
tf_idf_vect.fit(df['Clean_text'])
desc_matrix = tf_idf_vect.transform(df["Clean_text"])

# %%
# implement kmeans
num_clusters = 3
km = KMeans(n_clusters=num_clusters)
km.fit(desc_matrix)
clusters = km.labels_.tolist()

# %%
# create DataFrame films from all of the input files.
tweets = {'Tweet': df["Clean_text"].tolist(), 'Cluster': clusters}
frame = pd.DataFrame(tweets, index = [clusters])
frame
# Out:
#     Cluster                                              Tweet
# 1         1  indian look forward futur with renew sens opti...
# 1         1  leader opposit hurl wild alleg promot conspira...
# 1         1  report modi will address public meet foundat s...
